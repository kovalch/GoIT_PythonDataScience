# %%
import numpy as np
print(f"numpy version: {np.__version__}")
import pandas as pd
print(f"pandas version: {pd.__version__}")
import matplotlib.pyplot as plt
# Out:
# numpy version: 1.22.3
# pandas version: 1.4.3

# %%
table = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8#%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C"
                 , match='Коефіцієнт народжуваності в регіонах України ')
# with pd.read_html we will get a list of tables
len(table)
# Out:
# 1

# %%
df = table[0]
# check first (last) rows of the df
print(df.head(6))
print(df.tail())
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —
# 5       Житомирська  261.0  223.0  159.0   129    89   122  120   79
#           Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 23   Чернівецька  247.0  218.0  170.0   148   101   128  129   92
# 24  Чернігівська  220.0  183.0  127.0   108    69    94   90   61
# 25          Київ    NaN  174.0  159.0   120    73   120  121  110
# 26   Севастополь    NaN    NaN    NaN   125    70   120    —    —
# 27       Україна  228.0  205.0  152.0   126    78   114  111   81

# %%
# check the df info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Регіон  28 non-null     object
#  1   1950    26 non-null     float64
#  2   1960    27 non-null     float64
#  3   1970    27 non-null     float64
#  4   1990    28 non-null     int64
#  5   2000    28 non-null     int64
#  6   2012    28 non-null     int64
#  7   2014    28 non-null     object
#  8   2019    28 non-null     object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 2.1+ KB

# %%
# check df shape (#rows, #columns) and dtypes of each column
print(df.shape)
print(df.dtypes)
# Out:
# (28, 9)
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %%
# we see that some columns has dtype object, even though we are expecting them to be int/float
# these points us that some values are missing or have not numeric representation
# change "-" to NaN
df.replace(to_replace="—", value=np.nan, inplace=True)
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82  NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51  NaN
# ...

# %%
# check type of each column
print(df.dtypes)
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %%
# convert all columns but "Регіон" to numeric
df.loc[:, df.columns != 'Регіон'] = df.loc[:, df.columns != 'Регіон'].apply(pd.to_numeric, errors='coerce')
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0    NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# ...

# %%
#fill NaNs with column means in each column 
df = round(df.fillna(df.mean(numeric_only=True)),0)
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126  111.0   80.0
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0   80.0
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# ...

# %%
# get df only for 2019
df_2019 = pd.concat([df["Регіон"],df.iloc[:,-1:]],  axis=1)

# %%
print(df_2019.at[df_2019.index[-1],"2019"])
# Out:
# 81.0

# %%
# get df only for 2019
df_2019_largest = df_2019[df_2019["2019"] > df_2019.at[df_2019.index[-1],"2019"]]
df_2019_largest
# Out:
#                Регіон   2019
# 2           Волинська  101.0
# 6        Закарпатська  104.0
# 8   Івано-Франківська   88.0
# 12          Львівська   87.0
# 14            Одеська   88.0
# 16         Рівненська  107.0
# 23        Чернівецька   92.0
# 25               Київ  110.0

# %%
# get the region with max population in 2014
print(f" The max population in 2014 was in: {df.iloc[df['2014'].idxmax()]['Регіон']} Region")
# Out:
#  The max population in 2014 was in: Рівненська Region

# %%
# plot a bar diagram for 2019 vs Regions
plt.bar(df['Регіон'], df['2019'], width=0.5)
plt.tick_params(labelrotation = 90)
plt.title('Коефіцієнт народжуваності в 2019 році')
plt.show()

# %% [markdown]
# # Ploting of the results for HW #3

# %%
l_2019_largest_pop_reg = df_2019_largest["Регіон"].to_list()
l_2019_largest_pop_reg
# Out:
# ['Волинська',
#  'Закарпатська',
#  'Івано-Франківська',
#  'Львівська',
#  'Одеська',
#  'Рівненська',
#  'Чернівецька',
#  'Київ']

# %%
df_largest = df[df["Регіон"].isin(l_2019_largest_pop_reg)]
df_largest
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 12          Львівська  234.0  240.0  171.0   140    91   119  119.0   87.0
# 14            Одеська  241.0  192.0  148.0   126    80   127  123.0   88.0
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148.0  107.0
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129.0   92.0
# 25               Київ  231.0  174.0  159.0   120    73   120  121.0  110.0

# %%
# let us rotate/transpose df
df_largest_T = df_largest.set_index("Регіон").T
df_largest_T
# Out:
# Регіон  Волинська  Закарпатська  Івано-Франківська  Львівська  Одеська  \
# 1950        247.0         314.0              243.0      234.0    241.0
# 1960        250.0         273.0              248.0      240.0    192.0
# 1970        179.0         207.0              182.0      171.0    148.0
# 1990        153.0         168.0              155.0      140.0    126.0
# 2000        112.0         115.0              103.0       91.0     80.0
# 2012        148.0         151.0              124.0      119.0    127.0
# 2014        141.0         146.0              122.0      119.0    123.0
# 2019        101.0         104.0               88.0       87.0     88.0
#
# Регіон  Рівненська  Чернівецька   Київ
# 1950         269.0        247.0  231.0
# 1960         267.0        218.0  174.0
# 1970         193.0        170.0  159.0
# 1990         158.0        148.0  120.0
# 2000         118.0        101.0   73.0
# 2012         159.0        128.0  120.0
# 2014         148.0        129.0  121.0
# ...

# %%
df_largest_T.dtypes
# Out:
# Регіон
# Волинська            float64
# Закарпатська         float64
# Івано-Франківська    float64
# Львівська            float64
# Одеська              float64
# Рівненська           float64
# Чернівецька          float64
# Київ                 float64
# dtype: object

# %%
df_largest_T.plot()
plt.xlabel('Year', size = 15)
plt.ylabel('Population', size = 15)
plt.gcf().set_size_inches(18, 8)
plt.show()

# %%
df_largest_T.plot(y='Київ')
# Out:
# <AxesSubplot:>

# %%
df_largest_T.head(3).plot(kind='barh',figsize=(10,6))
# Out:
# <AxesSubplot:>
